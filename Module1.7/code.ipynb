# %% [markdown]
# missing value

# %%
import pandas as pd
data=pd.read_csv("data.csv")

data["Age"]=data["Age"].fillna(data["Age"].mean())
print(data)
# Out:
#     Age  Marks
# 0  20.0     50
# 1  21.0     60
# 2  22.0     70

# %% [markdown]
# categorical data encoding

# %%
from sklearn.preprocessing import LabelEncoder

data=pd.DataFrame({"name":["anwar","rakib","korim","babul","opu"],"age":[34,45,12,34,56]})
le=LabelEncoder()
data["name"]=le.fit_transform(data["name"])
print(data)
# Out:
#    name  age
# 0     0   34
# 1     4   45
# 2     2   12
# 3     1   34
# 4     3   56
